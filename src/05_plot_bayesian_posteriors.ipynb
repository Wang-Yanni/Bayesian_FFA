# %%
from plotting_utils import *

# %% [markdown]
# # Harricana River

# %% [markdown]
# ## Marginal and trace plot

# %%
samples_lp3 = np.load(r'C:\ISYE6420\Homework\Project\data\HRA\HRA_bayesian_lp3_samples.npy')

samples_flattened_lp3 = samples_lp3.reshape(-1, samples_lp3.shape[-1])

parameter_names_lp3 = ['μ', 'σ', 'γ']

marginal_plot(parameter_names_lp3, samples_flattened_lp3, 
              [(2.21, 2.35), (0.06, 0.2), (-1, 0.75)], 
              [0.02, 0.02, 0.25], 
              [(0, 40), (0, 60), (0, 3)], [10, 20, 1], 
              ['blue', 'limegreen', 'red'], r'C:\ISYE6420\Homework\Project\data\HRA\HRA_posterior_marginal_lp3.png')

trace_plot(parameter_names_lp3, samples_lp3, (0, 2000), 
              [(2.21, 2.35), (0.06, 0.2), (-1, 0.75)], 
              [0.02, 0.02, 0.25], 
           0.3, r'C:\ISYE6420\Homework\Project\data\HRA\HRA_posterior_trace_lp3.png')
