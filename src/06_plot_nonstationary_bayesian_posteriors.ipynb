# %%
from plotting_utils import *

# %% [markdown]
# # OC Dam

# %% [markdown]
# ## Stationary

# %%
samples_lp3 = np.load(r'C:\ISYE6420\Homework\Project\data\OCD\OCD_bayesian_stationary_lp3_samples.npy')

samples_flattened_lp3 = samples_lp3.reshape(-1, samples_lp3.shape[-1])

parameter_names_lp3 = ['μ', 'σ', 'γ']

marginal_plot(parameter_names_lp3, samples_flattened_lp3, 
              [(1, 1.7), (0.4, 1.1), (-0.9, 1.2)], 
              [0.1, 0.1, 0.3], 
              [(0, 8), (0, 12.5), (0, 3)], [10, 20, 1], 
              ['blue', 'limegreen', 'red'], r'C:\ISYE6420\Homework\Project\data\OCD\OCD_stationary_posterior_marginal_lp3.png')

trace_plot(parameter_names_lp3, samples_lp3, (0, 2000), 
           [(1, 1.7), (0.4, 1.1), (-0.9, 1.2)], 
           [0.1, 0.1, 0.3], 
           0.3, r'C:\ISYE6420\Homework\Project\data\OCD\OCD_stationary_posterior_trace_lp3.png')

# %% [markdown]
# ## Non-stationary

# %% [markdown]
# ### $\mu$: linear trend

# %%
samples_lp3 = np.load(r'C:\ISYE6420\Homework\Project\data\OCD\OCD_bayesian_linear_mu_lp3_samples.npy')

samples_flattened_lp3 = samples_lp3.reshape(-1, samples_lp3.shape[-1])

parameter_names_lp3 = ['β0','β1','σ', 'γ']

marginal_plot(parameter_names_lp3, samples_flattened_lp3, 
              [(1.5, 2.3), (-0.019, -0.003), (0.45, 0.85), (-1, 1)], 
              [0.1, 0.002, 0.05, 0.25], 
              [(0, 6), (0, 300), (0, 15), (0, 3)], [10, 20, 1], 
              ['blue', 'limegreen', 'red', 'purple'], r'C:\ISYE6420\Homework\Project\data\OCD\OCD_linear_mu_posterior_marginal_lp3.png')

trace_plot(parameter_names_lp3, samples_lp3, (0, 2000), 
              [(1.5, 2.3), (-0.019, -0.003), (0.45, 0.85), (-1, 1)], 
              [0.1, 0.002, 0.05, 0.25], 
           0.3, r'C:\ISYE6420\Homework\Project\data\OCD\OCD_linear_mu_posterior_trace_lp3.png')

# %% [markdown]
# ### $\mu$: exponential trend

# %%
samples_lp3 = np.load(r'C:\ISYE6420\Homework\Project\data\OCD\OCD_bayesian_exponential_mu_lp3_samples.npy')

samples_flattened_lp3 = samples_lp3.reshape(-1, samples_lp3.shape[-1])

parameter_names_lp3 = ['β0','β1','σ', 'γ']

marginal_plot(parameter_names_lp3, samples_flattened_lp3, 
              [(1.4, 2.6), (-0.019, -0.003), (0.45, 0.85), (-1, 1)], 
              [0.15, 0.002, 0.05, 0.25], 
              [(0, 5), (0, 400), (0, 15), (0, 3)], [10, 20, 1], 
              ['blue', 'limegreen', 'red', 'purple'], r'C:\ISYE6420\Homework\Project\data\OCD\OCD_exponential_mu_posterior_marginal_lp3.png')

trace_plot(parameter_names_lp3, samples_lp3, (0, 2000), 
              [(1.4, 2.6), (-0.017, -0.001), (0.45, 0.85), (-1, 1)], 
              [0.15, 0.002, 0.05, 0.25], 
           0.3, r'C:\ISYE6420\Homework\Project\data\OCD\OCD_exponential_mu_posterior_trace_lp3.png')
